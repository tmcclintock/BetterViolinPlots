# %% [markdown]
# # Violin plot gallery
#
# Here you will find a gallery of all versions of the violin plots that can be created with this package.

# %%
# Imports to set up the plots
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "../bvp/")  # for development only. remove later
from plots import analytic_violin, boxplot, kde_violin

# %% [markdown]
# ## Analytic violin plot
#
# One violin plot method unavailable in either `matplotlib` or `seaborn` is the ability to create violin plots of distributions known ahead of time. This is often useful when plotting reward distributions for reinforcement learnign experiments, or prior distributions for a set of variables on the same measure.
#
# Below you will see a simple example: a violin plot with five violins where three distributions are Gaussian (normal) distribtuions with random means and two distributions are poisson with a mean of three.

# %%
# Create some distributions
distributions = [stats.norm(loc=np.random.rand()*3) for _ in range(3)]
distributions += [stats.poisson(mu=3) for _ in range(2)]

# %%
analytic_violin(distributions)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11c5bd820>)

# %%
analytic_violin(distributions, fill=True)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11e6735e0>)

# %%
analytic_violin(distributions, vertical_violins=False)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11e7a5d60>)

# %%
analytic_violin(distributions, sides="left")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11e880bb0>)

# %% [markdown]
# ## KDE violin plots (i.e. the usual method)
#
# The `kde_violin` function is the standard method by which violin plots are created, in which a set of random points are passed that are kernelized to make an estimate of the underlying analytic distribution.
#
# Below you will find an example of using draws (random sampes) from the distributions in the previous example.

# %%
points = [d.rvs(size=20) for d in distributions]

# %%
fig, ax = kde_violin(points)

# %%
fig, ax = kde_violin(points, inner="stick")

# %%
fig, ax = kde_violin(points, inner="stick", vertical_violins=False)

# %%
fig, ax = kde_violin(points, sides="right", inner="stick")
analytic_violin(distributions, axis=ax, sides="left")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x127041190>)

# %%
fig, ax = kde_violin(points, inner="quartiles", vertical_violins=False)

# %%
fig, ax = kde_violin(points, inner="quartiles", vertical_violins=True)

# %%
# Boxplot example
boxplot_kwargs = {"boxprops": {"facecolor": "green"}}
fig, ax = boxplot(points, vertical_violins=True, boxplot_kwargs=boxplot_kwargs)
